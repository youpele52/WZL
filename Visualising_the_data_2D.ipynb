# %% [markdown]
# # Viewing the db files individually

# %%
# importing lib and packages
import sqlite3
import pandas as pd
from npfeintool import FeatEx
from npfeintool import CON
from npfeintool.analyzer import Analyzer

# %%
#save the names of database files in an array
name_of_db_1 = ["DiCo_digital_coil_M1_M2_Stempel_1_punches"]

# %%
#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_1, cutting_index):

    #load data into a dataframe
    df = pd.DataFrame()
    df = CON.load_all_segments("", name)
# Out:
# start loading DiCo_digital_coil_M1_M2_Stempel_1_punches.db
# Finished loading all 294 segments!

# %%
df.head()
# Out:
#             0           1           2           3           4           5  \
# 0  1261.92576  1453.44156  1249.15804  1134.24856  1134.24856  1019.33908
# 1  1236.39032  1478.97700  1261.92576  1134.24856  1134.24856  1032.10680
# 2  1261.92576  1491.74472  1261.92576  1095.94540  1108.71312  1044.87452
# 3  1274.69348  1478.97700  1261.92576  1108.71312  1134.24856  1044.87452
# 4  1274.69348  1466.20928  1261.92576  1121.48084  1147.01628  1044.87452
#
#             6          7          8          9  ...         281         282  \
# 0  1019.33908  942.73276  942.73276  878.89416  ...  1261.92576  1236.39032
# 1   981.03592  929.96504  929.96504  891.66188  ...  1261.92576  1223.62260
# 2  1006.57136  917.19732  917.19732  891.66188  ...  1249.15804  1236.39032
# 3  1006.57136  917.19732  942.73276  866.12644  ...  1287.46120  1210.85488
# 4  1019.33908  942.73276  942.73276  891.66188  ...  1223.62260  1223.62260
#
#           283         284         285         286         287         288  \
# 0  1236.39032  1249.15804  1261.92576  1312.99664  1261.92576  1274.69348
# 1  1249.15804  1261.92576  1300.22892  1274.69348  1274.69348  1300.22892
# 2  1261.92576  1261.92576  1312.99664  1300.22892  1325.76436  1261.92576
# 3  1274.69348  1249.15804  1287.46120  1287.46120  1312.99664  1287.46120
# 4  1261.92576  1249.15804  1300.22892  1287.46120  1325.76436  1325.76436
#
#           289         290
# 0  1351.29980  1338.53208
# 1  1300.22892  1338.53208
# 2  1312.99664  1351.29980
# 3  1325.76436  1338.53208
# 4  1312.99664  1325.76436
#
# [5 rows x 291 columns]

# %%
 # Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected = pca.fit_transform(df)

# %%
# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected[:, 0], projected[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()

# %%
# For the second db file


#save the names of database files in an array
name_of_db_2 = ["DiCo_digital_coil_M2_M3_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_2, cutting_index):

    #load data into a dataframe
    df2 = pd.DataFrame()
    df2 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected2 = pca.fit_transform(df2)

df2.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected2[:, 0], projected2[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M2_M3_Stempel_1_punches.db
# Finished loading all 140 segments!

# %%
# For the third db file


#save the names of database files in an array
name_of_db_3 = ["DiCo_digital_coil_M3_M4_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_3, cutting_index):

    #load data into a dataframe
    df3 = pd.DataFrame()
    df3 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected3 = pca.fit_transform(df3)

df3.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected3[:, 0], projected3[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M3_M4_Stempel_1_punches.db
# Finished loading all 246 segments!

# %%
# For the fourth db file


#save the names of database files in an array
name_of_db_4 = ["DiCo_digital_coil_M4_M5_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_4, cutting_index):

    #load data into a dataframe
    df4 = pd.DataFrame()
    df4 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected4 = pca.fit_transform(df4)

df4.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected4[:, 0], projected4[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M4_M5_Stempel_1_punches.db
# Finished loading all 426 segments!

# %%
# For the fifth db file


#save the names of database files in an array
name_of_db_5 = ["DiCo_digital_coil_M5_M6_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_5, cutting_index):

    #load data into a dataframe
    df5 = pd.DataFrame()
    df5 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected5 = pca.fit_transform(df5)

df5.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected5[:, 0], projected5[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M5_M6_Stempel_1_punches.db
# Finished loading all 261 segments!

# %%
# For the sixth db file


#save the names of database files in an array
name_of_db_6 = ["DiCo_digital_coil_M6_M7_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_6, cutting_index):

    #load data into a dataframe
    df6 = pd.DataFrame()
    df6 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected6 = pca.fit_transform(df6)

df6.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected6[:, 0], projected6[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M6_M7_Stempel_1_punches.db
# Finished loading all 167 segments!

# %%
# For the seventh db file


#save the names of database files in an array
name_of_db_7 = ["DiCo_digital_coil_M7_M8_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_7, cutting_index):

    #load data into a dataframe
    df7 = pd.DataFrame()
    df7 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected7 = pca.fit_transform(df7)

df7.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected7[:, 0], projected7[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M7_M8_Stempel_1_punches.db
# Finished loading all 207 segments!

# %%
# For the eighth db file


#save the names of database files in an array
name_of_db_8 = ["DiCo_digital_coil_M8_M9_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_8, cutting_index):

    #load data into a dataframe
    df8 = pd.DataFrame()
    df8 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected8 = pca.fit_transform(df8)

df8.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected8[:, 0], projected8[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M8_M9_Stempel_1_punches.db
# Finished loading all 259 segments!

# %%
# For the ninth db file


#save the names of database files in an array
name_of_db_9 = ["DiCo_digital_coil_M9_M10_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_9, cutting_index):

    #load data into a dataframe
    df9 = pd.DataFrame()
    df9 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected9 = pca.fit_transform(df9)

df9.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected9[:, 0], projected9[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M9_M10_Stempel_1_punches.db
# Finished loading all 243 segments!

# %%
# For the tenth db file


#save the names of database files in an array
name_of_db_10 = ["DiCo_digital_coil_M10_5_M11_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_10, cutting_index):

    #load data into a dataframe
    df10 = pd.DataFrame()
    df10 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected10 = pca.fit_transform(df10)

df10.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected10[:, 0], projected10[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M10_5_M11_Stempel_1_punches.db
# Finished loading all 391 segments!

# %%
# For the eleventh db file


#save the names of database files in an array
name_of_db_11 = ["DiCo_digital_coil_M10_M10_5_Stempel_1_punches"]

#current indices at which the segments should be cutted
cutting_index = [2399, 1499, 799]



#iterating over all database files and extracting features for every single database
for name, index in zip(name_of_db_11, cutting_index):

    #load data into a dataframe
    df11 = pd.DataFrame()
    df11 = CON.load_all_segments("", name)
    


# Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected11 = pca.fit_transform(df11)

df10.head()

# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected11[:, 0], projected11[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M10_M10_5_Stempel_1_punches.db
# Finished loading all 141 segments!

# %% [markdown]
# # Visualizing all the db files as one

# %% [markdown]
# There seems to be problem

# %%
import sqlite3
import pandas as pd
from npfeintool import FeatEx
from npfeintool import CON
from npfeintool.analyzer import Analyzer



#save the names of database files in an array, important if you want to change them without .db at the end
names_databases = ["DiCo_digital_coil_M1_M2_Stempel_1_punches", 
                    "DiCo_digital_coil_M2_M3_Stempel_1_punches", 
                    "DiCo_digital_coil_M3_M4_Stempel_1_punches",
                    "DiCo_digital_coil_M4_M5_Stempel_1_punches",
                    "DiCo_digital_coil_M5_M6_Stempel_1_punches",
                    "DiCo_digital_coil_M6_M7_Stempel_1_punches",
                    "DiCo_digital_coil_M7_M8_Stempel_1_punches",
                    "DiCo_digital_coil_M8_M9_Stempel_1_punches",
                    "DiCo_digital_coil_M9_M10_Stempel_1_punches",
                    "DiCo_digital_coil_M10_5_M11_Stempel_1_punches",
                    "DiCo_digital_coil_M10_M10_5_Stempel_1_punches",
                    ]

#current indices at which the segments should be cutted
cutting_index = [1500,1500,1500,1500,1500,1500,1500,1500,1500,1500,1500,1500,]


#iterating over all database files and extracting features for every single database
for name, index in zip(names_databases, cutting_index):

    #load data into a dataframe
    df = pd.DataFrame()
    df = CON.load_all_segments("", name)
    
 # Applying PCA
from sklearn.decomposition import PCA # inmporting the lib of pca
pca = PCA(n_components = 2)
projected = pca.fit_transform(df)



# Visualize 2D Projection
import matplotlib
import matplotlib.pyplot as plt


plt.scatter(projected[:, 0], projected[:, 1])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid()
# Out:
# start loading DiCo_digital_coil_M1_M2_Stempel_1_punches.db
# Finished loading all 294 segments!
# start loading DiCo_digital_coil_M2_M3_Stempel_1_punches.db
# Finished loading all 140 segments!
# start loading DiCo_digital_coil_M3_M4_Stempel_1_punches.db
# Finished loading all 246 segments!
# start loading DiCo_digital_coil_M4_M5_Stempel_1_punches.db
# Finished loading all 426 segments!
# start loading DiCo_digital_coil_M5_M6_Stempel_1_punches.db
# Finished loading all 261 segments!
# start loading DiCo_digital_coil_M6_M7_Stempel_1_punches.db
# Finished loading all 167 segments!
# start loading DiCo_digital_coil_M7_M8_Stempel_1_punches.db
# Finished loading all 207 segments!
# start loading DiCo_digital_coil_M8_M9_Stempel_1_punches.db
# Finished loading all 259 segments!
# start loading DiCo_digital_coil_M9_M10_Stempel_1_punches.db
# Finished loading all 243 segments!
# start loading DiCo_digital_coil_M10_5_M11_Stempel_1_punches.db
# Finished loading all 391 segments!
# start loading DiCo_digital_coil_M10_M10_5_Stempel_1_punches.db
# Finished loading all 141 segments!

# %% [markdown]
# # Clustering

# %% [markdown]
# After joining all the databases (loading all the databases), PCA and visualising it. The figure is very similar to the figure for the eleventh db file. Something is wrong, I will need some time to discover what the problem and how to fix it, or you can give me the solution.

# %%
# importing lib and packages
import sqlite3
import pandas as pd
from npfeintool import FeatEx
from npfeintool import CON
from npfeintool.analyzer import Analyzer

# %%
#save the names of database files in an array, important if you want to change them without .db at the end
names_databases = ["DiCo_digital_coil_M1_M2_Stempel_1_punches", 
                    "DiCo_digital_coil_M2_M3_Stempel_1_punches", 
                    "DiCo_digital_coil_M3_M4_Stempel_1_punches",
                    "DiCo_digital_coil_M4_M5_Stempel_1_punches",
                    "DiCo_digital_coil_M5_M6_Stempel_1_punches",
                    "DiCo_digital_coil_M6_M7_Stempel_1_punches",
                    "DiCo_digital_coil_M7_M8_Stempel_1_punches",
                    "DiCo_digital_coil_M8_M9_Stempel_1_punches",
                    "DiCo_digital_coil_M9_M10_Stempel_1_punches",
                    "DiCo_digital_coil_M10_5_M11_Stempel_1_punches",
                    "DiCo_digital_coil_M10_M10_5_Stempel_1_punches"
                    ]

# %%
#current indices at which the segments should be cutted
cutting_index = [1500,1500,1500,1500,1500,1500,1500,1500,1500,1500,1500,1500,]

#iterating over all database files and extracting features for every single database
for name, index in zip(names_databases, cutting_index):

    #load data into a dataframe
    df = pd.DataFrame()
    df = CON.load_all_segments("", name)
    #df = df.truncate(before=0, after=1499)
    #df_transpose = df.transpose()
    #df_no_missing = df_transpose.dropna().values # Remove signal with missing data
# Out:
# start loading DiCo_digital_coil_M1_M2_Stempel_1_punches.db
# Finished loading all 294 segments!
# start loading DiCo_digital_coil_M2_M3_Stempel_1_punches.db
# Finished loading all 140 segments!
# start loading DiCo_digital_coil_M3_M4_Stempel_1_punches.db
# Finished loading all 246 segments!
# start loading DiCo_digital_coil_M4_M5_Stempel_1_punches.db
# Finished loading all 426 segments!
# start loading DiCo_digital_coil_M5_M6_Stempel_1_punches.db
# Finished loading all 261 segments!
# start loading DiCo_digital_coil_M6_M7_Stempel_1_punches.db
# Finished loading all 167 segments!
# start loading DiCo_digital_coil_M7_M8_Stempel_1_punches.db
# Finished loading all 207 segments!
# start loading DiCo_digital_coil_M8_M9_Stempel_1_punches.db
# Finished loading all 259 segments!
# start loading DiCo_digital_coil_M9_M10_Stempel_1_punches.db
# Finished loading all 243 segments!
# start loading DiCo_digital_coil_M10_5_M11_Stempel_1_punches.db
# Finished loading all 391 segments!
# start loading DiCo_digital_coil_M10_M10_5_Stempel_1_punches.db
# Finished loading all 141 segments!

# %%
 # Applying PCA
from sklearn.decomposition import PCA # importing the lib of pca
pca = PCA(n_components = 3)
X = pca.fit_transform(df)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


# Using the elbow method to find the number of clusters
from sklearn.cluster import KMeans # importing the KMeans class from its lib
wcss = [] # wcss is used to find the optimal number of clusters
for i in range (1,11): # creating a for loop
    kmeans = KMeans(n_clusters= i, init = 'k-means++', max_iter = 300, n_init= 10, random_state= 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss) 
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Applying kmeans to the datasets

kmeans = KMeans(n_clusters= 2, init = 'k-means++', max_iter = 300, n_init= 10, random_state= 0) # Fitting to the right number of clusters predicted by the elbow method above
y_kmeans = kmeans.fit_predict(X) 

# Visualing the clusters 
plt.scatter(X[y_kmeans==0,0], X[y_kmeans==0,1], s =5, c= 'red', label = 'Cluster 1') 
plt.scatter(X[y_kmeans==1,0], X[y_kmeans==1,1], s =5, c= 'green', label = 'Cluster 2') 
plt.scatter(X[y_kmeans==2,0], X[y_kmeans==2,1], s =5, c= 'blue', label = 'Cluster 3')
plt.scatter(X[y_kmeans==3,0], X[y_kmeans==3,1], s =5, c= 'cyan', label = 'Cluster 4') 
#plt.scatter(X[y_kmeans==4,0], X[y_kmeans==4,1], s =100, c= 'pink', label = 'Cluster 5') 
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Data Clusters')
plt.legend()
plt.grid()
plt.show()

# %%
# Applying kmeans to the datasets, 3 clusters

kmeans = KMeans(n_clusters= 3, init = 'k-means++', max_iter = 300, n_init= 10, random_state= 0) # Fitting to the right number of clusters predicted by the elbow method above
y_kmeans = kmeans.fit_predict(X) 

# Visualing the clusters 
plt.scatter(X[y_kmeans==0,0], X[y_kmeans==0,1], s =5, c= 'red', label = 'Cluster 1') 
plt.scatter(X[y_kmeans==1,0], X[y_kmeans==1,1], s =5, c= 'green', label = 'Cluster 2') 
plt.scatter(X[y_kmeans==2,0], X[y_kmeans==2,1], s =5, c= 'blue', label = 'Cluster 3')
plt.scatter(X[y_kmeans==3,0], X[y_kmeans==3,1], s =5, c= 'cyan', label = 'Cluster 4') 
#plt.scatter(X[y_kmeans==4,0], X[y_kmeans==4,1], s =100, c= 'pink', label = 'Cluster 5') 
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Data Clusters')
plt.legend()
plt.grid()
plt.show()
